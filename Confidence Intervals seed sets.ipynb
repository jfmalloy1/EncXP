# %%
import pandas as pd
import json
import os
from collections import Counter
import itertools
import re
import csv
import random
import statsmodels.stats.weightstats as sms

import matplotlib.pyplot as mpl
import seaborn as sns

import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np

# %% [markdown]
# ### Read Files
#
# Read compounds found on Enceladus (Enceladus_Compounds_and_Concentrations), compounds necessary for life (Freileich), and files associated with each run.

# %%
#read seed set KEGG labels and names into a dictionary
with open("Enceladus_Compounds_and_Concentrations.csv") as f2:
  next(f2)
  lb = []
  reader = csv.reader(f2, skipinitialspace=True)
  for row in reader:
    lb.append(tuple([row[0], row[2]]))

lb = dict(lb)
print(lb)
# Out:
# {'C00011': 'CO2', 'C01407': 'C6H6', 'C00014': 'NH3', 'C00283': 'H2S', 'C00282': 'H2', 'C06548': 'C2H4O', 'C01438': 'CH4', 'C00697': 'N2', 'C06547': 'C2H4', 'C00132': 'CH4O', 'C00067': 'CH2O', 'C11505': 'C3H6', 'C01548': 'C2H2', 'C00469': 'C2H6O', 'C00001': 'H20', 'C20783': 'C3H8', 'C01326': 'HCN', 'C00237': 'CO'}

# %%
#Revised KEGG compounds and names
data = json.load(open("containskegg_and_majorspecies.json"))
lb = []

cpd_name_df = pd.read_csv("accessible_compounds.csv")
for cpd in data["Contains_KEGGID"]:
    df_row = cpd_name_df[cpd_name_df["Compound"] == cpd]
    lb.append(tuple([cpd, df_row.iloc[0]["Name"]]))
    
lb = dict(lb)
print(lb)
# Out:
# {u'C00027': 'Hydrogen peroxide', u'C12568': 'Potassium hydroxide', u'C18606': 'Potassium bicarbonate', u'C00283': 'Hydrogen sulfide', u'C00282': 'Hydrogen', u'C00007': 'Oxygen', u'C00288': 'HCO3-', u'C00001': 'H2O', u'C01380': 'Ethylene glycol', u'C01387': 'Octane', u'C06548': 'Ethylene oxide', u'C19316': 'Allyl chloride', u'C00741': 'Diacetyl', u'C06142': '1-Butanol', u'C01328': 'HO-', u'C00533': 'Nitric oxide', u'C01438': 'Methane', u'C06547': 'Ethylene', u'C11505': 'Propylene', u'C00238': 'Potassium cation', u'C01548': 'Acetylene', u'C00218': 'Methylamine', u'C00479': 'Propanal', u'C13563': 'Sodium chloride', u'C12603': 'Sodium bicarbonate', u'C01326': 'Hydrogen cyanide', u'C00011': 'CO2', u'C00014': 'Ammonia', u'C00132': 'Methanol', u'C01059': '2,5-Dihydroxypyridine', u'C00067': 'Formaldehyde', u'C21390': 'Butane', u'C20783': 'Propane', u'C19572': 'Silica', u'C12567': 'Magnesium oxide', u'C05979': 'Propane-1-ol', u'C12569': 'Sodium hydroxide', u'C01407': 'Benzene', u'C00266': 'Glycolaldehyde', u'C17390': 'Polybutene', u'C00041': 'L-Alanine', u'C12244': '3-Buten-1-amine', u'C01353': 'Carbonic acid', u'C00469': 'Ethanol', u'C00189': 'Ethanolamine', u'C01330': 'Sodium cation', u'C00237': 'CO', u'C00543': 'Dimethylamine', u'C00697': 'Nitrogen'}

# %%
#Remove 11 compounds with no reactions associated with them
extra_cpds = ['C00238','C12244','C12567','C12568','C12569','C12603','C13563','C17390','C18606','C19316','C19572']
for cpd in extra_cpds:
    lb.pop(cpd)
    
print(lb)
print(len(lb))
# Out:
# {u'C00027': 'Hydrogen peroxide', u'C00283': 'Hydrogen sulfide', u'C00282': 'Hydrogen', u'C00007': 'Oxygen', u'C00288': 'HCO3-', u'C00001': 'H2O', u'C01380': 'Ethylene glycol', u'C01387': 'Octane', u'C06548': 'Ethylene oxide', u'C00741': 'Diacetyl', u'C06142': '1-Butanol', u'C01328': 'HO-', u'C00533': 'Nitric oxide', u'C01438': 'Methane', u'C06547': 'Ethylene', u'C11505': 'Propylene', u'C01548': 'Acetylene', u'C00218': 'Methylamine', u'C00479': 'Propanal', u'C01326': 'Hydrogen cyanide', u'C00011': 'CO2', u'C00014': 'Ammonia', u'C00132': 'Methanol', u'C01059': '2,5-Dihydroxypyridine', u'C00067': 'Formaldehyde', u'C21390': 'Butane', u'C20783': 'Propane', u'C05979': 'Propane-1-ol', u'C01407': 'Benzene', u'C00266': 'Glycolaldehyde', u'C00041': 'L-Alanine', u'C01353': 'Carbonic acid', u'C00469': 'Ethanol', u'C00189': 'Ethanolamine', u'C01330': 'Sodium cation', u'C00237': 'CO', u'C00543': 'Dimethylamine', u'C00697': 'Nitrogen'}
# 38

# %%
#define life-specifc reactions
freilich = "links/Freilich09.json"
with open(freilich) as fr:
   datajsonfr = json.load(fr)
    
lc = datajsonfr.keys()
print(lc)
# Out:
# [u'C00025', u'C00024', u'C00148', u'C00105', u'C00362', u'C00020', u'C00360', u'C00008', u'C15672', u'C00006', u'C00005', u'C00004', u'C00003', u'C00002', u'C00144', u'C00079', u'C00364', u'C05980', u'C00458', u'C00399', u'C01050', u'C00407', u'C00239', u'C16221', u'C00748', u'C00054', u'C00055', u'C00350', u'C00641', u'C06040', u'C00073', u'C00062', u'C00234', u'C00063', u'C00097', u'C00135', u'C00037', u'C00078', u'C00035', u'C05764', u'C00015', u'C00016', u'C00112', u'C00065', u'C00116', u'C00152', u'C00131', u'C00064', u'C00001', u'C00075', u'C00123', u'C00459', u'C05899', u'C00082', u'C00249', u'C00255', u'C00286', u'C05890', u'C05894', u'C00043', u'C00041', u'C00047', u'C00188', u'C00044', u'C00049', u'C00183']

# %% [markdown]
# ### Open and organize expansions
#
# Find all expansions that result in life-specific compounds

# %%
#folder = "5nw", etc... (classification of each analysis)
def multiple_files(folder, n_files):
    #life reaction array
    life_reactions = []

    #files that contain expanded networks
    ex_files = []

    #Open path
    path = "results/formatted/"+folder
    files = os.listdir(path)
    
    for filename in random.sample(files, n_files):
        if ".json" in filename:
            with open(path + "/" + filename) as f:
              datajson = json.load(f)
              #Organize data by each generation
              generations = pd.DataFrame(datajson["generations"])
              generations = generations.transpose()
              generations.index = generations.index.astype(int)
              generations = generations.sort_index()

              #Test
              #generations.head()

              #List of cumulative compounds
              cum_compounds = generations.loc[: , "compounds_cumulative"]
              fc = cum_compounds.tail(1).tolist()

              fc = fc[0]
              #print(fc)

              #find all life-specifc reactions
              life = list(set(fc).intersection(lc))

              #add reactions to the list of total reactions found in previous expansions
              life_reactions.append(life)

              #Get the number of the run if the number of life reactions is greater than 0
              #Purpose - to find the seed compounds in original.dat file
              if (len(life) != 0):
                run = re.findall('\d+', filename)
                ex_files.append(int(run[0]))

    return life_reactions, ex_files

# %%
#label compounds from KEGG
#count the number of reactions that occur
def label_and_count(lifereactions, life_reactions):
  #read output KEGG labels and names into a dictionary##
  file = open("links/Freilich09.json")
  file_data = file.read()
  output_labels = json.loads(file_data)

  #NOTE: sum only useful for first time through - after, comment it out
  lifereactions = sum(lifereactions, [])

  #translate KEGG labels into formulas
  for l in lifereactions:
    life_reactions.append(output_labels[l])


  #count the number of times a compound occurs
  life_count = Counter(life_reactions)
  return life_count

# %% [markdown]
# ### Find distribution of seed sets that result in expanded networks

# %%
#access data file
def data_file(file, labels, ex_files):
  path = file

  #list of all generated seeds
  seeds = []
  s = open(path)
  for line in s:
    seeds.append(line.split())
  s.close()

  #find all seed sets that resulted in an expanded network
  life_seeds = []
  lifeseeds = [] #properly labeled version
  for n in ex_files:
    life_seeds.append(seeds[n])
  
  #sum only works first time through
  life_seeds = sum(life_seeds, [])
  
  #translate KEGG labels into formulas
  for l in life_seeds:
    try:
        lifeseeds.append(lb[l])
    except:
        print(l + " doesn't work")

  life_seed_count = Counter(lifeseeds)
  
  return life_seed_count

# %%
def analyze(filename, n):
  #analyze the runs stored in a folder
  lifereactions, ex_files = multiple_files(filename, n)
  #count the number of times each compound appears
  life_count = label_and_count(lifereactions, [])
  dat_file = "seeds/rseeds_" + filename + ".txt"
  life_seed_count = data_file(dat_file, lb, ex_files)
 
  return life_seed_count

# %%
#analyze data folders
#first analysis
#count_10nw = analyze("10nw", 25)
#count_5nw = analyze("5nw", 25)
#count_5w = analyze("5w", 25)
#count_10w = analyze("10w", 25)
count_10nw_random = analyze("10nw_random_V2", 25)
count_10nw_fixed = analyze("10nw_fixed_V2", 25)

#life_total = count_5nw + count_5w + count_10w + count_10nw
life_total = count_10nw_random + count_10nw_fixed
life_list = []
life_list.append(life_total)

#Loop through 100 random samples (1st is above) to obtain a full sample
for i in range(99):
#     count_5nw = analyze("5nw", 25)
#     count_5w = analyze("5w", 25)
#     count_10w = analyze("10w", 25)
#     count_10nw = analyze("10nw", 25)
    count_10nw_random = analyze("10nw_random", 25)
    count_10nw_fixed = analyze("10nw_fixed", 25)

    #life = count_5nw + count_5w + count_10w + count_10nw
    life = count_10nw_random + count_10nw_fixed
    life_total += life
    life_list.append(life)
    print(str(i) + "\n-----")
    print(life)
    print("-----")
    
print("TOTAL")
print(life_total)
# Out:
# C00238 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# 0
# -----
# Counter({'Ammonia': 31, 'H2O': 31, 'CO2': 29, 'Methane': 28, 'Hydrogen': 27, 'Nitric oxide': 12, 'Nitrogen': 12, 'Dimethylamine': 12, 'Sodium cation': 11, 'Ethylene': 10, 'Formaldehyde': 10, 'Acetylene': 10, 'Benzene': 10, 'Ethanol': 9, 'L-Alanine': 9, 'HO-': 8, 'Carbonic acid': 8, '2,5-Dihydroxypyridine': 7, 'Propane': 7, 'Hydrogen sulfide': 7, 'Hydrogen peroxide': 7, 'Butane': 6, '1-Butanol': 6, 'Oxygen': 6, 'Glycolaldehyde': 6, 'Ethylene glycol': 6, 'Propane-1-ol': 6, 'Methanol': 5, 'HCO3-': 5, 'Propylene': 5, 'Methylamine': 5, 'Octane': 5, 'Hydrogen cyanide': 4, 'Diacetyl': 4, 'Propanal': 4, 'Ethanolamine': 4, 'Ethylene oxide': 4, 'CO': 3})
# -----
# C18606 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# 1
# -----
# Counter({'CO2': 31, 'Ammonia': 31, 'Hydrogen': 31, 'Methane': 28, 'H2O': 28, 'Ethylene oxide': 12, 'Hydrogen peroxide': 12, 'Diacetyl': 10, 'Propylene': 10, 'Nitrogen': 10, 'Methanol': 9, 'Ethanol': 9, 'Benzene': 9, 'L-Alanine': 9, 'Propanal': 9, 'Ethylene': 8, 'Nitric oxide': 8, 'Oxygen': 8, 'Glycolaldehyde': 8, 'Carbonic acid': 8, 'Sodium cation': 7, 'HCO3-': 7, 'Propane': 7, 'Formaldehyde': 7, 'Acetylene': 7, 'Dimethylamine': 7, '2,5-Dihydroxypyridine': 6, 'Butane': 6, 'CO': 6, 'Ethanolamine': 6, 'Methylamine': 6, 'Ethylene glycol': 6, 'Propane-1-ol': 6, 'Hydrogen cyanide': 5, 'Octane': 5, '1-Butanol': 4, 'HO-': 3, 'Hydrogen sulfide': 3})
# -----
# C18606 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# 2
# -----
# Counter({'Ammonia': 33, 'CO2': 32, 'H2O': 31, 'Hydrogen': 31, 'Methane': 28, 'Acetylene': 14, 'Ethylene glycol': 12, 'Formaldehyde': 11, 'Ethylene': 10, 'Oxygen': 10, 'Dimethylamine': 10, 'Carbonic acid': 10, 'Methanol': 9, 'Diacetyl': 9, 'Propane': 9, 'HO-': 9, 'Nitric oxide': 9, 'Benzene': 9, 'Ethylene oxide': 9, 'Sodium cation': 8, 'Hydrogen cyanide': 8, 'Propylene': 8, '1-Butanol': 8, 'Hydrogen sulfide': 8, 'Methylamine': 8, 'Butane': 7, 'L-Alanine': 7, 'Octane': 7, '2,5-Dihydroxypyridine': 6, 'CO': 6, 'Ethanolamine': 6, 'Propane-1-ol': 5, 'HCO3-': 4, 'Glycolaldehyde': 4, 'Hydrogen peroxide': 4, 'Nitrogen': 4, 'Ethanol': 3, 'Propanal': 3})
# -----
# C12567 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C19316 doesn't work
# 3
# -----
# Counter({'CO2': 31, 'H2O': 30, 'Methane': 29, 'Hydrogen': 29, 'Ammonia': 28, 'Dimethylamine': 13, 'Propane-1-ol': 13, 'L-Alanine': 12, 'Hydrogen peroxide': 12, 'Propylene': 11, 'Ethanol': 11, 'Glycolaldehyde': 10, '2,5-Dihydroxypyridine': 10, 'Benzene': 9, 'Methanol': 8, 'Propane': 8, 'Carbonic acid': 8, 'Hydrogen cyanide': 7, 'HO-': 7, 'Formaldehyde': 7, 'Ethanolamine': 7, 'Nitrogen': 7, 'HCO3-': 6, 'Nitric oxide': 6, 'CO': 6, 'Oxygen': 6, 'Acetylene': 6, 'Ethylene glycol': 6, 'Ethylene': 5, 'Propanal': 5, '1-Butanol': 5, 'Hydrogen sulfide': 5, 'Methylamine': 5, 'Octane': 5, 'Diacetyl': 4, 'Butane': 4, 'Sodium cation': 3, 'Ethylene oxide': 3})
# -----
# C19316 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# 4
# -----
# Counter({'Hydrogen': 31, 'CO2': 30, 'Ammonia': 30, 'Methane': 29, 'H2O': 28, 'Carbonic acid': 16, 'Hydrogen cyanide': 12, 'Dimethylamine': 12, 'Methylamine': 11, 'L-Alanine': 10, 'Propane-1-ol': 10, 'Formaldehyde': 9, 'Hydrogen peroxide': 9, 'Sodium cation': 8, 'HO-': 8, '1-Butanol': 8, 'Benzene': 8, 'Ethylene glycol': 8, '2,5-Dihydroxypyridine': 7, 'Butane': 7, 'Nitric oxide': 7, 'Oxygen': 7, 'Nitrogen': 7, 'HCO3-': 6, 'Diacetyl': 6, 'Propane': 6, 'Glycolaldehyde': 6, 'Octane': 6, 'Ethanol': 5, 'CO': 5, 'Acetylene': 5, 'Propanal': 5, 'Ethylene oxide': 5, 'Propylene': 4, 'Hydrogen sulfide': 4, 'Ethanolamine': 4, 'Ethylene': 3, 'Methanol': 3})
# -----
# C19316 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C12603 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# 5
# -----
# Counter({'CO2': 34, 'Methane': 29, 'Ammonia': 29, 'Hydrogen': 29, 'H2O': 28, 'Benzene': 14, 'Ethylene': 10, 'Propane': 9, 'Butane': 9, 'Methylamine': 9, 'Ethylene oxide': 9, 'Nitrogen': 9, 'Sodium cation': 8, 'Hydrogen cyanide': 8, 'HO-': 8, 'Formaldehyde': 8, 'Nitric oxide': 8, '1-Butanol': 8, 'Ethylene glycol': 8, 'Methanol': 7, 'Ethanol': 7, 'Glycolaldehyde': 7, 'Hydrogen sulfide': 7, 'L-Alanine': 7, 'Hydrogen peroxide': 7, 'Carbonic acid': 7, 'Propane-1-ol': 7, 'Diacetyl': 6, 'CO': 6, 'Ethanolamine': 6, 'HCO3-': 5, '2,5-Dihydroxypyridine': 5, 'Oxygen': 5, 'Propanal': 5, 'Propylene': 4, 'Octane': 4, 'Acetylene': 3, 'Dimethylamine': 3})
# -----
# C18606 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# 6
# -----
# Counter({'Hydrogen': 32, 'CO2': 30, 'Methane': 29, 'H2O': 27, 'Ammonia': 27, '2,5-Dihydroxypyridine': 11, 'Carbonic acid': 11, 'Hydrogen peroxide': 10, 'Ethylene': 9, 'Propane': 9, 'Ethanol': 9, '1-Butanol': 9, 'Glycolaldehyde': 9, 'Hydrogen sulfide': 9, 'Dimethylamine': 9, 'Octane': 9, 'Hydrogen cyanide': 8, 'Propylene': 8, 'Nitric oxide': 8, 'Oxygen': 8, 'Ethylene glycol': 8, 'Sodium cation': 7, 'Methanol': 7, 'Diacetyl': 7, 'CO': 7, 'Ethanolamine': 7, 'Benzene': 7, 'Nitrogen': 7, 'HO-': 6, 'Formaldehyde': 6, 'Butane': 6, 'Acetylene': 6, 'Propanal': 5, 'HCO3-': 4, 'L-Alanine': 4, 'Propane-1-ol': 4, 'Ethylene oxide': 3, 'Methylamine': 2})
# -----
# C12603 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C19316 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C19572 doesn't work
# 7
# -----
# Counter({'Ammonia': 35, 'H2O': 33, 'Methane': 30, 'CO2': 30, 'Hydrogen': 29, 'Methylamine': 11, 'Ethylene oxide': 11, 'Ethylene glycol': 11, 'Hydrogen cyanide': 10, 'Glycolaldehyde': 10, 'Acetylene': 10, 'Hydrogen peroxide': 10, 'Nitric oxide': 9, 'Diacetyl': 8, 'Formaldehyde': 8, 'Benzene': 8, 'Octane': 8, 'Methanol': 7, 'HCO3-': 7, '2,5-Dihydroxypyridine': 7, 'Ethanol': 7, 'Butane': 7, 'Propanal': 7, 'Propane': 6, '1-Butanol': 6, 'Oxygen': 6, 'Ethanolamine': 6, 'L-Alanine': 6, 'Nitrogen': 6, 'Carbonic acid': 6, 'Ethylene': 5, 'Propylene': 5, 'Hydrogen sulfide': 5, 'Dimethylamine': 5, 'Sodium cation': 4, 'HO-': 4, 'CO': 4, 'Propane-1-ol': 4})
# -----
# C12244 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# 8
# -----
# Counter({'Hydrogen': 33, 'H2O': 32, 'CO2': 31, 'Methane': 30, 'Ammonia': 28, 'Methylamine': 14, 'L-Alanine': 14, 'Dimethylamine': 11, 'Ethanol': 10, 'Ethylene oxide': 10, 'Acetylene': 10, 'Oxygen': 9, 'Hydrogen peroxide': 9, 'Nitrogen': 9, 'Glycolaldehyde': 8, 'Hydrogen sulfide': 8, 'Ethanolamine': 8, 'Benzene': 8, 'Propane-1-ol': 8, 'Propylene': 7, 'Formaldehyde': 7, 'Butane': 7, 'Propanal': 7, 'Ethylene': 6, 'Hydrogen cyanide': 6, 'Methanol': 6, 'Diacetyl': 6, 'HO-': 6, 'Nitric oxide': 6, 'Carbonic acid': 6, 'Ethylene glycol': 6, 'Sodium cation': 5, 'Propane': 5, 'Octane': 5, 'HCO3-': 4, '2,5-Dihydroxypyridine': 4, '1-Butanol': 3, 'CO': 3})
# -----
# C12567 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# 9
# -----
# Counter({'Methane': 32, 'Ammonia': 32, 'H2O': 29, 'CO2': 28, 'Hydrogen': 28, 'Ethanol': 13, 'Butane': 13, 'L-Alanine': 12, 'Propylene': 11, '1-Butanol': 11, 'Ethanolamine': 10, 'Methanol': 9, 'Nitric oxide': 9, 'Ethylene': 8, 'HO-': 8, 'Dimethylamine': 8, 'Propanal': 7, '2,5-Dihydroxypyridine': 7, 'Glycolaldehyde': 7, 'Hydrogen sulfide': 7, 'Ethylene oxide': 7, 'Nitrogen': 7, 'HCO3-': 6, 'Diacetyl': 6, 'Formaldehyde': 6, 'CO': 6, 'Oxygen': 6, 'Carbonic acid': 6, 'Ethylene glycol': 6, 'Propane': 5, 'Benzene': 5, 'Hydrogen peroxide': 5, 'Propane-1-ol': 5, 'Sodium cation': 4, 'Hydrogen cyanide': 4, 'Methylamine': 4, 'Octane': 4, 'Acetylene': 3})
# -----
# C00238 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# 10
# -----
# Counter({'CO2': 33, 'Ammonia': 33, 'H2O': 31, 'Methane': 29, 'Hydrogen': 29, '2,5-Dihydroxypyridine': 12, 'Hydrogen peroxide': 12, 'Oxygen': 11, 'Glycolaldehyde': 11, 'Benzene': 11, 'Formaldehyde': 10, 'L-Alanine': 10, 'Nitrogen': 10, 'Carbonic acid': 10, 'Hydrogen cyanide': 9, 'Propylene': 9, 'Ethanol': 9, 'Butane': 9, 'Methylamine': 9, 'Propane': 8, 'Acetylene': 8, 'Octane': 8, 'HCO3-': 7, 'Propanal': 7, 'Nitric oxide': 7, 'Ethylene glycol': 7, '1-Butanol': 6, 'Dimethylamine': 6, 'Propane-1-ol': 6, 'Sodium cation': 5, 'Methanol': 5, 'HO-': 5, 'CO': 5, 'Ethanolamine': 5, 'Ethylene': 4, 'Ethylene oxide': 4, 'Diacetyl': 3, 'Hydrogen sulfide': 3})
# -----
# C12244 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# 11
# -----
# Counter({'H2O': 32, 'Methane': 29, 'CO2': 29, 'Hydrogen': 28, 'Ammonia': 28, 'Oxygen': 12, 'Benzene': 11, 'Acetylene': 11, 'Ethylene oxide': 11, 'Ethanolamine': 10, 'Hydrogen peroxide': 10, 'Ethylene glycol': 10, 'Propane': 9, 'Propanal': 9, 'Glycolaldehyde': 9, 'Dimethylamine': 9, 'Methanol': 8, 'Diacetyl': 8, 'HO-': 8, 'Methylamine': 8, 'Carbonic acid': 8, 'Nitric oxide': 7, 'Hydrogen sulfide': 7, 'Octane': 7, 'Ethylene': 6, 'Sodium cation': 6, 'Hydrogen cyanide': 6, 'Ethanol': 6, 'Butane': 6, '1-Butanol': 6, 'Propylene': 5, 'L-Alanine': 5, 'Nitrogen': 5, 'Propane-1-ol': 5, '2,5-Dihydroxypyridine': 4, 'Formaldehyde': 4, 'HCO3-': 3, 'CO': 3})
# -----
# C19572 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# 12
# -----
# Counter({'Methane': 29, 'Ammonia': 29, 'H2O': 29, 'CO2': 27, 'Hydrogen': 27, 'Hydrogen peroxide': 11, 'Formaldehyde': 10, 'Ethanol': 10, 'Methylamine': 10, 'CO': 10, 'HCO3-': 9, '2,5-Dihydroxypyridine': 8, 'Propylene': 8, 'Ethylene oxide': 8, 'Carbonic acid': 8, 'Methanol': 7, 'Propanal': 7, 'Glycolaldehyde': 7, 'Ethylene': 6, 'Sodium cation': 6, 'Butane': 6, 'Hydrogen sulfide': 6, 'Dimethylamine': 6, 'Propane-1-ol': 6, 'Propane': 5, 'HO-': 5, '1-Butanol': 5, 'Ethanolamine': 5, 'Benzene': 5, 'Nitrogen': 5, 'L-Alanine': 4, 'Acetylene': 4, 'Ethylene glycol': 4, 'Hydrogen cyanide': 3, 'Diacetyl': 3, 'Nitric oxide': 3, 'Oxygen': 3, 'Octane': 1})
# -----
# C12603 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# 13
# -----
# Counter({'Ammonia': 28, 'Methane': 27, 'CO2': 27, 'Hydrogen': 27, 'H2O': 26, 'Propane': 12, 'HO-': 11, 'Nitrogen': 11, 'Hydrogen cyanide': 9, '2,5-Dihydroxypyridine': 9, 'Butane': 9, 'L-Alanine': 9, 'Benzene': 9, 'Ethylene glycol': 9, 'HCO3-': 8, 'Diacetyl': 8, 'Methylamine': 8, 'Acetylene': 8, 'Dimethylamine': 8, 'Sodium cation': 7, 'Propylene': 7, 'Ethanol': 7, '1-Butanol': 7, 'CO': 7, 'Hydrogen peroxide': 7, 'Carbonic acid': 7, 'Propanal': 6, 'Hydrogen sulfide': 6, 'Ethylene oxide': 6, 'Ethylene': 5, 'Formaldehyde': 5, 'Nitric oxide': 5, 'Oxygen': 5, 'Ethanolamine': 5, 'Octane': 5, 'Propane-1-ol': 5, 'Glycolaldehyde': 4, 'Methanol': 2})
# -----
# C13563 doesn't work
# C12603 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# 14
# -----
# Counter({'Ammonia': 29, 'H2O': 29, 'Hydrogen': 29, 'Methane': 28, 'CO2': 27, 'Methylamine': 10, 'Ethylene': 9, 'Formaldehyde': 9, 'Nitric oxide': 9, 'L-Alanine': 9, 'Nitrogen': 9, 'Ethylene glycol': 9, 'Dimethylamine': 9, 'Propane': 8, 'Butane': 8, 'Benzene': 8, 'Glycolaldehyde': 8, 'Ethanolamine': 8, 'Acetylene': 8, '2,5-Dihydroxypyridine': 7, 'Ethanol': 7, 'Oxygen': 7, 'Hydrogen peroxide': 7, 'Sodium cation': 6, 'HCO3-': 6, 'Propanal': 6, 'HO-': 6, 'Hydrogen sulfide': 6, 'Octane': 6, 'Propane-1-ol': 6, 'Hydrogen cyanide': 5, 'Ethylene oxide': 5, 'Carbonic acid': 5, '1-Butanol': 4, 'Methanol': 3, 'Diacetyl': 3, 'Propylene': 3, 'CO': 2})
# -----
# C12244 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C18606 doesn't work
# 15
# -----
# Counter({'H2O': 33, 'CO2': 32, 'Methane': 29, 'Hydrogen': 28, 'Ammonia': 27, 'Nitric oxide': 11, 'Benzene': 11, 'Ethanolamine': 11, 'Carbonic acid': 11, 'Propane': 9, 'HO-': 9, 'Ethylene': 8, 'Sodium cation': 8, 'Hydrogen cyanide': 8, 'Diacetyl': 8, 'Acetylene': 8, 'Propanal': 7, 'CO': 7, 'Glycolaldehyde': 7, 'Hydrogen sulfide': 7, 'Methylamine': 7, 'Dimethylamine': 7, 'Hydrogen peroxide': 7, 'Nitrogen': 7, 'Octane': 7, 'HCO3-': 6, 'Propylene': 6, 'Formaldehyde': 6, 'Oxygen': 6, 'Methanol': 5, 'Butane': 5, 'L-Alanine': 5, '2,5-Dihydroxypyridine': 5, 'Ethylene glycol': 5, 'Propane-1-ol': 5, 'Ethylene oxide': 3, 'Ethanol': 2, '1-Butanol': 2})
# -----
# C00238 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# 16
# -----
# Counter({'Ammonia': 32, 'H2O': 32, 'Hydrogen': 31, 'CO2': 30, 'Methane': 27, 'Sodium cation': 13, 'HCO3-': 11, 'Ethanol': 11, 'Ethanolamine': 11, 'Hydrogen peroxide': 11, 'L-Alanine': 10, 'Dimethylamine': 10, 'Propane-1-ol': 10, 'Ethylene': 9, 'Hydrogen cyanide': 9, 'Propylene': 9, 'Methylamine': 9, 'Nitrogen': 9, 'Propane': 8, 'HO-': 8, 'Nitric oxide': 8, 'CO': 7, 'Oxygen': 7, 'Hydrogen sulfide': 7, 'Acetylene': 7, 'Ethylene oxide': 7, 'Ethylene glycol': 7, 'Methanol': 6, 'Butane': 6, 'Glycolaldehyde': 6, 'Carbonic acid': 6, '2,5-Dihydroxypyridine': 5, 'Benzene': 5, '1-Butanol': 5, 'Diacetyl': 4, 'Propanal': 3, 'Octane': 3, 'Formaldehyde': 2})
# -----
# C12603 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# 17
# -----
# Counter({'Hydrogen': 32, 'Methane': 29, 'Ammonia': 28, 'CO2': 27, 'H2O': 26, 'Carbonic acid': 13, 'Ethanolamine': 10, 'Dimethylamine': 10, 'Propane-1-ol': 10, 'Ethylene': 9, 'Propanal': 9, 'Nitric oxide': 9, 'Methylamine': 9, 'Oxygen': 9, 'Hydrogen peroxide': 9, 'Nitrogen': 9, 'Ethylene glycol': 9, 'HCO3-': 8, 'Butane': 8, '1-Butanol': 8, 'Hydrogen sulfide': 8, 'Octane': 8, 'Methanol': 7, 'Diacetyl': 7, 'Propane': 7, 'HO-': 7, 'Formaldehyde': 7, 'Ethanol': 7, 'Glycolaldehyde': 7, 'L-Alanine': 6, 'CO': 5, 'Benzene': 5, 'Sodium cation': 4, 'Hydrogen cyanide': 4, 'Ethylene oxide': 4, 'Propylene': 3, 'Acetylene': 3, '2,5-Dihydroxypyridine': 2})
# -----
# C19316 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C13563 doesn't work
# C12603 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# 18
# -----
# Counter({'Ammonia': 33, 'CO2': 30, 'H2O': 30, 'Hydrogen': 30, 'Methane': 27, 'Hydrogen peroxide': 15, 'Sodium cation': 14, 'Dimethylamine': 14, 'Hydrogen sulfide': 13, 'Carbonic acid': 11, 'Hydrogen cyanide': 10, 'HO-': 10, 'Butane': 10, 'Acetylene': 10, 'Ethylene glycol': 10, 'Ethanolamine': 9, 'Propanal': 9, 'Ethylene oxide': 9, 'Nitrogen': 9, 'Propane': 8, 'Oxygen': 8, 'L-Alanine': 8, 'Octane': 8, '2,5-Dihydroxypyridine': 7, 'Ethanol': 7, 'Nitric oxide': 7, 'Methylamine': 7, 'HCO3-': 6, 'Diacetyl': 6, 'Formaldehyde': 6, 'Glycolaldehyde': 6, 'Propylene': 5, 'Benzene': 5, '1-Butanol': 4, 'Propane-1-ol': 4, 'Ethylene': 3, 'Methanol': 2, 'CO': 2})
# -----
# C13563 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# 19
# -----
# Counter({'CO2': 33, 'Hydrogen': 31, 'Methane': 30, 'Ammonia': 29, 'H2O': 29, '2,5-Dihydroxypyridine': 12, 'Nitric oxide': 12, 'Ethanol': 11, 'HCO3-': 10, 'Propylene': 10, 'Benzene': 10, 'Glycolaldehyde': 10, 'Hydrogen peroxide': 10, 'Carbonic acid': 10, 'HO-': 9, 'Ethanolamine': 9, 'Methylamine': 9, 'Nitrogen': 9, 'Propane-1-ol': 9, 'Ethylene': 8, 'Propane': 8, 'Formaldehyde': 8, 'Hydrogen sulfide': 8, 'L-Alanine': 8, 'Ethylene glycol': 8, 'Hydrogen cyanide': 7, 'Propanal': 7, 'Sodium cation': 6, 'Diacetyl': 6, 'Oxygen': 6, 'Ethylene oxide': 6, 'Dimethylamine': 6, 'Butane': 5, '1-Butanol': 5, 'CO': 4, 'Acetylene': 3, 'Octane': 3, 'Methanol': 2})
# -----
# C12567 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C19316 doesn't work
# 20
# -----
# Counter({'H2O': 34, 'Methane': 31, 'Hydrogen': 30, 'Ammonia': 28, 'CO2': 27, 'Propane': 12, 'HO-': 12, 'Hydrogen cyanide': 11, 'L-Alanine': 11, 'Carbonic acid': 11, 'Diacetyl': 10, 'Nitric oxide': 10, 'Oxygen': 10, 'Hydrogen sulfide': 10, 'Ethylene glycol': 10, 'HCO3-': 9, 'Propylene': 9, 'Butane': 9, 'Nitrogen': 9, 'Formaldehyde': 8, 'Methylamine': 8, 'Acetylene': 8, 'Octane': 8, 'Ethylene': 7, 'CO': 7, 'Glycolaldehyde': 7, 'Ethanolamine': 7, 'Propanal': 6, 'Ethanol': 6, 'Ethylene oxide': 6, 'Dimethylamine': 6, 'Hydrogen peroxide': 6, 'Propane-1-ol': 6, 'Sodium cation': 5, '1-Butanol': 5, 'Benzene': 5, 'Methanol': 4, '2,5-Dihydroxypyridine': 4})
# -----
# C19572 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C13563 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# 21
# -----
# ...
# C13563 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C12603 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# 92
# -----
# Counter({'Hydrogen': 32, 'CO2': 30, 'Methane': 29, 'H2O': 29, 'Ammonia': 28, 'Sodium cation': 12, 'Propylene': 12, 'HO-': 11, 'L-Alanine': 11, 'Hydrogen sulfide': 10, 'Ethylene': 9, 'Diacetyl': 9, 'Benzene': 9, '1-Butanol': 9, 'Octane': 9, 'Propane-1-ol': 9, 'Butane': 8, 'CO': 8, 'Propanal': 8, 'Carbonic acid': 8, 'Dimethylamine': 8, 'HCO3-': 7, 'Nitric oxide': 7, 'Ethanolamine': 7, 'Methylamine': 7, 'Ethylene glycol': 7, 'Methanol': 6, '2,5-Dihydroxypyridine': 6, 'Oxygen': 6, 'Hydrogen peroxide': 6, 'Nitrogen': 6, 'Propane': 5, 'Formaldehyde': 5, 'Ethanol': 5, 'Glycolaldehyde': 5, 'Acetylene': 5, 'Hydrogen cyanide': 4, 'Ethylene oxide': 2})
# -----
# C12244 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# 93
# -----
# Counter({'Hydrogen': 34, 'Ammonia': 33, 'Methane': 30, 'CO2': 28, 'H2O': 26, 'Propylene': 12, 'Octane': 11, 'Diacetyl': 10, 'Hydrogen peroxide': 10, 'Ethylene': 9, 'Sodium cation': 9, 'Methanol': 9, 'CO': 9, 'L-Alanine': 9, 'Carbonic acid': 9, 'Hydrogen sulfide': 8, 'Ethanolamine': 8, 'Nitrogen': 8, 'Propanal': 7, 'Ethanol': 7, 'Butane': 7, 'Nitric oxide': 7, 'Oxygen': 7, 'Ethylene glycol': 7, 'Propane': 6, 'Benzene': 6, 'HO-': 5, 'Glycolaldehyde': 5, 'Ethylene oxide': 5, 'Acetylene': 5, 'Dimethylamine': 5, 'Propane-1-ol': 5, 'Hydrogen cyanide': 4, 'HCO3-': 4, 'Methylamine': 4, '1-Butanol': 3, '2,5-Dihydroxypyridine': 3, 'Formaldehyde': 2})
# -----
# C19572 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C12603 doesn't work
# C12603 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# 94
# -----
# Counter({'H2O': 32, 'Ammonia': 30, 'Hydrogen': 30, 'Methane': 28, 'CO2': 27, 'Carbonic acid': 16, 'Propane-1-ol': 12, 'HCO3-': 11, 'Propane': 10, 'Nitric oxide': 10, 'CO': 10, 'Glycolaldehyde': 10, 'Ethanolamine': 10, 'L-Alanine': 10, 'Formaldehyde': 8, 'Propanal': 8, 'Ethanol': 8, 'Oxygen': 8, 'Nitrogen': 8, 'Sodium cation': 7, 'Hydrogen cyanide': 7, 'Propylene': 7, 'Benzene': 7, '1-Butanol': 7, 'HO-': 6, 'Octane': 6, 'Ethylene': 5, 'Acetylene': 5, 'Hydrogen peroxide': 5, 'Methanol': 4, 'Diacetyl': 4, '2,5-Dihydroxypyridine': 4, 'Butane': 4, 'Hydrogen sulfide': 4, 'Ethylene oxide': 4, 'Ethylene glycol': 4, 'Dimethylamine': 4, 'Methylamine': 1})
# -----
# C12567 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C18606 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C18606 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# 95
# -----
# Counter({'H2O': 31, 'Methane': 30, 'Hydrogen': 29, 'CO2': 28, 'Ammonia': 28, 'Hydrogen cyanide': 13, 'Ethylene glycol': 13, 'Hydrogen sulfide': 12, 'Propane': 11, 'Sodium cation': 10, 'HO-': 10, 'Dimethylamine': 10, 'Methanol': 9, 'Propylene': 9, 'Octane': 9, 'CO': 8, 'Ethylene oxide': 8, 'Carbonic acid': 8, 'Ethylene': 7, 'Diacetyl': 7, 'Nitric oxide': 7, 'Methylamine': 7, 'Glycolaldehyde': 7, 'Hydrogen peroxide': 7, 'HCO3-': 6, '2,5-Dihydroxypyridine': 6, 'Oxygen': 6, 'L-Alanine': 6, 'Formaldehyde': 5, 'Ethanol': 5, 'Butane': 5, '1-Butanol': 5, 'Acetylene': 5, 'Ethanolamine': 5, 'Benzene': 5, 'Nitrogen': 5, 'Propanal': 4, 'Propane-1-ol': 4})
# -----
# C12603 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C12569 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C12603 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C12568 doesn't work
# C12568 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# 96
# -----
# Counter({'H2O': 30, 'CO2': 29, 'Hydrogen': 28, 'Ammonia': 27, 'Methane': 26, 'Ethylene glycol': 11, 'Butane': 10, 'Methylamine': 10, '1-Butanol': 10, 'Carbonic acid': 10, 'Oxygen': 9, 'L-Alanine': 9, 'Dimethylamine': 9, 'Hydrogen peroxide': 9, 'Glycolaldehyde': 8, 'Hydrogen sulfide': 8, 'Benzene': 8, 'Propane-1-ol': 8, 'Hydrogen cyanide': 7, 'Propanal': 7, 'Ethanol': 7, 'Propylene': 6, 'CO': 6, 'Octane': 6, 'Sodium cation': 5, 'Methanol': 5, 'HCO3-': 5, 'Diacetyl': 5, 'Propane': 5, 'Formaldehyde': 5, 'Nitric oxide': 5, 'Nitrogen': 5, 'Ethylene': 4, '2,5-Dihydroxypyridine': 4, 'HO-': 4, 'Ethylene oxide': 4, 'Acetylene': 4, 'Ethanolamine': 2})
# -----
# C12603 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C00238 doesn't work
# C12244 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C19316 doesn't work
# C12569 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C12567 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C13563 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C12569 doesn't work
# C13563 doesn't work
# C18606 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C12568 doesn't work
# C13563 doesn't work
# C19572 doesn't work
# C12603 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C12568 doesn't work
# C17390 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# 97
# -----
# Counter({'CO2': 31, 'Methane': 30, 'H2O': 30, 'Ammonia': 29, 'Hydrogen': 28, 'Ethylene glycol': 16, 'Propane': 12, 'HO-': 10, 'Methylamine': 10, 'Nitrogen': 10, 'Butane': 9, 'Nitric oxide': 9, 'L-Alanine': 9, 'Propylene': 8, 'Formaldehyde': 8, 'Benzene': 8, 'Ethanolamine': 8, 'Propanal': 8, 'Dimethylamine': 8, 'Octane': 8, 'Methanol': 7, 'Diacetyl': 7, 'Ethylene oxide': 7, 'Carbonic acid': 7, 'Hydrogen cyanide': 6, 'Ethanol': 6, '1-Butanol': 6, 'CO': 6, 'Propane-1-ol': 6, 'HCO3-': 5, '2,5-Dihydroxypyridine': 5, 'Acetylene': 5, 'Ethylene': 4, 'Sodium cation': 4, 'Oxygen': 4, 'Glycolaldehyde': 4, 'Hydrogen peroxide': 4, 'Hydrogen sulfide': 3})
# -----
# C12568 doesn't work
# C18606 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C12568 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C12244 doesn't work
# C18606 doesn't work
# C13563 doesn't work
# C12567 doesn't work
# C12567 doesn't work
# C19572 doesn't work
# C19316 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C17390 doesn't work
# C12603 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C19572 doesn't work
# C17390 doesn't work
# C00238 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C13563 doesn't work
# C17390 doesn't work
# C12569 doesn't work
# C12568 doesn't work
# C12603 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C19316 doesn't work
# C18606 doesn't work
# C12244 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C12244 doesn't work
# C19316 doesn't work
# C17390 doesn't work
# C13563 doesn't work
# C12244 doesn't work
# C19572 doesn't work
# C12567 doesn't work
# C12569 doesn't work
# C12569 doesn't work
# C12567 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C12567 doesn't work
# C18606 doesn't work
# C17390 doesn't work
# C19316 doesn't work
# C00238 doesn't work
# C00238 doesn't work
# C18606 doesn't work
# C19572 doesn't work
# C13563 doesn't work
# C12569 doesn't work
# C18606 doesn't work
# 98
# -----
# Counter({'CO2': 32, 'Ammonia': 31, 'H2O': 28, 'Hydrogen': 28, 'Methane': 26, 'Carbonic acid': 15, 'Hydrogen cyanide': 11, 'HO-': 10, 'Nitric oxide': 10, 'Propane-1-ol': 10, 'Sodium cation': 9, 'Nitrogen': 9, 'Methanol': 8, 'Propane': 8, 'Formaldehyde': 8, 'Ethanol': 8, 'Methylamine': 8, 'Ethylene': 7, 'Propanal': 7, 'Propylene': 7, 'CO': 7, 'Dimethylamine': 7, 'Hydrogen peroxide': 7, 'Octane': 7, 'Butane': 6, 'Glycolaldehyde': 6, 'Hydrogen sulfide': 6, 'Ethylene glycol': 6, 'Diacetyl': 5, '2,5-Dihydroxypyridine': 5, '1-Butanol': 5, 'Oxygen': 5, 'Ethanolamine': 5, 'L-Alanine': 5, 'Ethylene oxide': 5, 'Acetylene': 5, 'HCO3-': 4, 'Benzene': 4})
# -----
# TOTAL
# Counter({'Ammonia': 2986, 'CO2': 2985, 'H2O': 2981, 'Hydrogen': 2968, 'Methane': 2880, 'Carbonic acid': 879, 'Hydrogen peroxide': 853, 'Ethylene glycol': 829, 'L-Alanine': 813, 'Dimethylamine': 790, 'Propane': 777, 'Nitrogen': 774, 'Nitric oxide': 763, 'Hydrogen sulfide': 750, 'HO-': 742, 'Ethanol': 730, 'Benzene': 729, 'Propylene': 721, 'Oxygen': 721, 'Methylamine': 721, 'Formaldehyde': 719, 'Ethanolamine': 706, 'Ethylene': 702, 'Hydrogen cyanide': 694, 'Sodium cation': 691, 'Butane': 689, 'Glycolaldehyde': 687, 'Methanol': 685, 'Ethylene oxide': 681, '2,5-Dihydroxypyridine': 671, 'Propane-1-ol': 666, 'Acetylene': 664, 'Octane': 650, '1-Butanol': 647, 'HCO3-': 646, 'Diacetyl': 645, 'Propanal': 630, 'CO': 583})

# %%
#For each element: have a numpy array of the expansion sizes (for average and 95% confidence intervals)
count = 0
for cpd in life_total:
    count += 1
    print(cpd)
    cpd_array = []
    for l in life_list:
        cpd_array.append(int(l[cpd]))
    cpd_array = np.asarray(cpd_array)
    print("Average: " + str(np.average(cpd_array)))
    print("Confidence interval: " + str(sms.DescrStatsW(cpd_array).tconfint_mean(alpha=0.05))+ "\n")
    
print(count)
# Out:
# Ethylene
# Average: 7.02
# Confidence interval: (6.544740908452543, 7.495259091547456)
#
# Sodium cation
# Average: 6.91
# Confidence interval: (6.410972335508798, 7.4090276644912025)
#
# Hydrogen cyanide
# Average: 6.94
# Confidence interval: (6.446804054016447, 7.433195945983554)
#
# Methanol
# Average: 6.85
# Confidence interval: (6.387123428148282, 7.312876571851717)
#
# HCO3-
# Average: 6.46
# Confidence interval: (5.978555496321954, 6.941444503678046)
#
# Diacetyl
# Average: 6.45
# Confidence interval: (5.963661351451594, 6.936338648548406)
#
# 2,5-Dihydroxypyridine
# Average: 6.71
# Confidence interval: (6.270100824504582, 7.149899175495418)
#
# Propane
# Average: 7.77
# Confidence interval: (7.298205263552427, 8.241794736447572)
#
# HO-
# Average: 7.42
# Confidence interval: (6.973919899228234, 7.866080100771766)
#
# Propylene
# Average: 7.21
# Confidence interval: (6.766499387580785, 7.653500612419215)
#
# Formaldehyde
# Average: 7.19
# Confidence interval: (6.677914195980376, 7.7020858040196245)
#
# Ethanol
# Average: 7.3
# Confidence interval: (6.831041811043799, 7.7689581889562005)
#
# Butane
# Average: 6.89
# Confidence interval: (6.435341286949837, 7.344658713050162)
#
# Nitric oxide
# Average: 7.63
# Confidence interval: (7.12498350402262, 8.135016495977379)
#
# Methane
# Average: 28.8
# Confidence interval: (28.47720841533514, 29.12279158466486)
#
# Benzene
# Average: 7.29
# Confidence interval: (6.822064797734868, 7.7579352022651324)
#
# 1-Butanol
# Average: 6.47
# Confidence interval: (5.981149263368473, 6.958850736631526)
#
# CO
# Average: 5.83
# Confidence interval: (5.391223272117811, 6.268776727882189)
#
# Oxygen
# Average: 7.21
# Confidence interval: (6.748052261134187, 7.671947738865813)
#
# Glycolaldehyde
# Average: 6.87
# Confidence interval: (6.419948037369893, 7.3200519626301075)
#
# Hydrogen sulfide
# Average: 7.5
# Confidence interval: (6.978064491406133, 8.021935508593867)
#
# CO2
# Average: 29.85
# Confidence interval: (29.43900337834704, 30.260996621652964)
#
# Ethanolamine
# Average: 7.06
# Confidence interval: (6.538582874594011, 7.581417125405988)
#
# L-Alanine
# Average: 8.13
# Confidence interval: (7.697062818474172, 8.562937181525829)
#
# Propanal
# Average: 6.3
# Confidence interval: (5.884073887664295, 6.715926112335705)
#
# Methylamine
# Average: 7.21
# Confidence interval: (6.743767655335266, 7.676232344664734)
#
# Ethylene oxide
# Average: 6.81
# Confidence interval: (6.311291208152415, 7.308708791847584)
#
# Acetylene
# Average: 6.64
# Confidence interval: (6.149472226548272, 7.130527773451727)
#
# Dimethylamine
# Average: 7.9
# Confidence interval: (7.389621691461985, 8.410378308538014)
#
# H2O
# Average: 29.81
# Confidence interval: (29.3891359896166, 30.230864010383396)
#
# Hydrogen peroxide
# Average: 8.53
# Confidence interval: (8.01887809378987, 9.04112190621013)
#
# Nitrogen
# Average: 7.74
# Confidence interval: (7.231870753032693, 8.248129246967308)
#
# Carbonic acid
# Average: 8.79
# Confidence interval: (8.229278489837407, 9.350721510162591)
#
# Ethylene glycol
# Average: 8.29
# Confidence interval: (7.745105226141476, 8.834894773858522)
#
# Hydrogen
# Average: 29.68
# Confidence interval: (29.301750819694583, 30.058249180305417)
#
# Ammonia
# Average: 29.86
# Confidence interval: (29.47742281325476, 30.24257718674524)
#
# Octane
# Average: 6.5
# Confidence interval: (6.085990608058998, 6.914009391941002)
#
# Propane-1-ol
# Average: 6.66
# Confidence interval: (6.207687153104879, 7.112312846895121)
#
# 38
